# %% [markdown]
# # **Install Packages**

# %%
# !pip install -r "/gait_biometric_identification/requirements.txt"

# %% [markdown]
# # **Train AI Model**

# %%
# !python "/gait_biometric_identification/scripts/train.py"
